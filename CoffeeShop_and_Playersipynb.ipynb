# %% [markdown]
# <a href="https://colab.research.google.com/github/Boshra-01/Machine-Learning-Practices/blob/main/CoffeeShop_and_Playersipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Coffee Shop Data

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
coffee.head(3)
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
# getting random sample data to get idea of dataset:
coffee.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 4   Wednesday    Espresso          35
# 8      Friday    Espresso          45
# 13     Sunday       Latte          35
# 1      Monday       Latte          15

# %%
coffee["Units Sold"]
# Out:
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %% [markdown]
# ### Functions: loc, iloc

# %% [markdown]
# #### loc

# %%
#coffee.loc[row, column]
coffee.loc[0:2] #using slicer-this is will return only rows from index 0 to 2
coffee.loc[0:]
coffee.loc[[0,2,5]]
coffee.loc[0:] # 0 to all
coffee.loc[0:3, "Coffee Type"]
coffee.loc["Sunday": "Monday", ["Day", "Coffee Type"]]
coffee.loc[0:3, ["Day", "Coffee Type"]]
# Out:
#        Day Coffee Type
# 0   Monday    Espresso
# 1   Monday       Latte
# 2  Tuesday    Espresso
# 3  Tuesday       Latte

# %%
#modify a value inside dataset:
coffee.loc[1, "Units Sold"] = 10
#modify multiple values inside dataset:
coffee.loc[[1,3], "Units Sold"] = 10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %% [markdown]
# #### iloc

# %%
# iloc only understnds index's, not names of columns
coffee.iloc[0:3, [0,1]]
# Out:
#        Day Coffee Type
# 0   Monday    Espresso
# 1   Monday       Latte
# 2  Tuesday    Espresso

# %% [markdown]
# ### Add / Remove columns

# %%
#adding column
coffee['price'] = 5.00

# %%
coffee.head(3)
# Out:
#        Day Coffee Type  Units Sold  price
# 0   Monday    Espresso          25    5.0
# 1   Monday       Latte          10    5.0
# 2  Tuesday    Espresso          30    5.0

# %%
#putting each type of coffee's price
import numpy as np

coffee['new_price'] = np.where(coffee['Coffee Type']== 'Espresso', 3.50, 4.50)

# %%
coffee.head(5)
# Out:
#          Day Coffee Type  Units Sold  price  new_price
# 0     Monday    Espresso          25    5.0        3.5
# 1     Monday       Latte          10    5.0        4.5
# 2    Tuesday    Espresso          30    5.0        3.5
# 3    Tuesday       Latte          10    5.0        4.5
# 4  Wednesday    Espresso          35    5.0        3.5

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 3     Tuesday       Latte          10    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 6    Thursday    Espresso          40    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 8      Friday    Espresso          45    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 10   Saturday    Espresso          45    5.0        3.5
# 11   Saturday       Latte          35    5.0        4.5
# 12     Sunday    Espresso          45    5.0        3.5
# 13     Sunday       Latte          35    5.0        4.5

# %%
# Add a new row using loc[]
coffee.loc[len(coffee)] = ["Sunday", "Mocha", 35, 5.0, 4.5]
print(coffee)
coffee.loc[len(coffee)] = ["Wednesday", "Mocha", 35, 5.0, 4.5]
print(coffee)
coffee.loc[len(coffee)] = ["Monday", "Mocha", 35, 5.0, 4.5]
print(coffee)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 3     Tuesday       Latte          10    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 6    Thursday    Espresso          40    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 8      Friday    Espresso          45    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 10   Saturday    Espresso          45    5.0        3.5
# 11   Saturday       Latte          35    5.0        4.5
# 12     Sunday    Espresso          45    5.0        3.5
# 13     Sunday       Latte          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 3     Tuesday       Latte          10    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 6    Thursday    Espresso          40    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 8      Friday    Espresso          45    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 10   Saturday    Espresso          45    5.0        3.5
# 11   Saturday       Latte          35    5.0        4.5
# 12     Sunday    Espresso          45    5.0        3.5
# 13     Sunday       Latte          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
# 15  Wednesday       Mocha          35    5.0        4.5
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 3     Tuesday       Latte          10    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 6    Thursday    Espresso          40    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 8      Friday    Espresso          45    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 10   Saturday    Espresso          45    5.0        3.5
# 11   Saturday       Latte          35    5.0        4.5
# 12     Sunday    Espresso          45    5.0        3.5
# 13     Sunday       Latte          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
# 15  Wednesday       Mocha          35    5.0        4.5
# 16     Monday       Mocha          35    5.0        4.5

# %% [markdown]
# ### deleeting duplicate records

# %%
#deleting duplicate records:

coffee_cleaned = coffee.drop_duplicates()
print(coffee_cleaned)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 3     Tuesday       Latte          10    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 6    Thursday    Espresso          40    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 8      Friday    Espresso          45    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 10   Saturday    Espresso          45    5.0        3.5
# 11   Saturday       Latte          35    5.0        4.5
# 12     Sunday    Espresso          45    5.0        3.5
# 13     Sunday       Latte          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
# 15  Wednesday       Mocha          35    5.0        4.5
# 16     Monday       Mocha          35    5.0        4.5

# %% [markdown]
# ### Sorting

# %%
coffee.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 8      Friday    Espresso          45    5.0        3.5
# 12     Sunday    Espresso          45    5.0        3.5
# 10   Saturday    Espresso          45    5.0        3.5
# 6    Thursday    Espresso          40    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 15  Wednesday       Mocha          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
# 13     Sunday       Latte          35    5.0        4.5
# 11   Saturday       Latte          35    5.0        4.5
# 16     Monday       Mocha          35    5.0        4.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 0      Monday    Espresso          25    5.0        3.5
# 1      Monday       Latte          10    5.0        4.5
# 3     Tuesday       Latte          10    5.0        4.5

# %%
coffee.sort_values(["Units Sold","Coffee Type", "Day"], ascending=False) # "Coffee Type", "Day" are strings, so those will be in alphabetical orders
coffee.sort_values(["Units Sold","Coffee Type", "Day"], ascending=[0,1,1]) # 0/1 - it changes ascending/descendng orders of 3 entries: "Units Sold","Coffee Type", "Day"
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 8      Friday    Espresso          45    5.0        3.5
# 10   Saturday    Espresso          45    5.0        3.5
# 12     Sunday    Espresso          45    5.0        3.5
# 6    Thursday    Espresso          40    5.0        3.5
# 4   Wednesday    Espresso          35    5.0        3.5
# 9      Friday       Latte          35    5.0        4.5
# 11   Saturday       Latte          35    5.0        4.5
# 13     Sunday       Latte          35    5.0        4.5
# 16     Monday       Mocha          35    5.0        4.5
# 14     Sunday       Mocha          35    5.0        4.5
# 15  Wednesday       Mocha          35    5.0        4.5
# 2     Tuesday    Espresso          30    5.0        3.5
# 7    Thursday       Latte          30    5.0        4.5
# 0      Monday    Espresso          25    5.0        3.5
# 5   Wednesday       Latte          25    5.0        4.5
# 1      Monday       Latte          10    5.0        4.5
# 3     Tuesday       Latte          10    5.0        4.5

# %% [markdown]
# ## Players Data

# %% [markdown]
# ### Filtering Data

# %%
players = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv')

# %%
players.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
#get idea of the datatypes of each column
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
# using loc function
players.loc[players['height_cm'] > 210]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19  Moskva (Moscow)
# 5572          5595        Santiago Aldama  1968-12-07             Quel
# 5583          5606   Paulinho Villas Boas  1963-01-26        São Paulo
# 5599          5622      Vladimir Andreyev  1945-06-14        Astrakhan
# 5609          5632        Franjo Arapović  1965-06-02              NaN
# ...            ...                    ...         ...              ...
# 140298      143804       Aaron Geramipoor  1992-09-11        Stockport
# 141018      144554          Yuta Watanabe  1994-10-13  Ayauta district
# 142044      145640          Jahlil Okafor  1995-12-15       Fort Smith
# 142930      146560             Mike Tobey  1994-10-10           Monroe
# 143712      147367           JaVale McGee  1988-01-19            Flint
#
#        born_region born_country                       NOC  height_cm  \
# 5089        Moskva          RUS              Soviet Union      220.0
# 5572      La Rioja          ESP                     Spain      213.0
# 5583     São Paulo          BRA                    Brazil      217.0
# 5599     Astrakhan          RUS              Soviet Union      215.0
# 5609           NaN          NaN        Croatia Yugoslavia      211.0
# ...            ...          ...                       ...        ...
# 140298     England          GBR  Islamic Republic of Iran      214.0
# 141018      Kagawa          JPN                     Japan      215.0
# 142044    Arkansas          USA                   Nigeria      211.0
# 142930    New York          USA                  Slovenia      213.0
# 143712    Michigan          USA             United States      213.0
#
#         weight_kg   died_date
# 5089        112.0  1993-07-24
# 5572         98.0         NaN
# 5583        106.0         NaN
# 5599         90.0         NaN
# 5609        120.0         NaN
# ...           ...         ...
# 140298        NaN         NaN
# 141018       97.0         NaN
# 142044        NaN         NaN
# 142930        NaN         NaN
# 143712        NaN         NaN
#
# [150 rows x 10 columns]

# %%
#putting conditions:
players.loc[players['height_cm'] > 210, ['born_country','height_cm']]
# Out:
#        born_country  height_cm
# 5089            RUS      220.0
# 5572            ESP      213.0
# 5583            BRA      217.0
# 5599            RUS      215.0
# 5609            NaN      211.0
# ...             ...        ...
# 140298          GBR      214.0
# 141018          JPN      215.0
# 142044          USA      211.0
# 142930          USA      213.0
# 143712          USA      213.0
#
# [150 rows x 2 columns]

# %%
#without loc function
players[players['height_cm'] > 210]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19  Moskva (Moscow)
# 5572          5595        Santiago Aldama  1968-12-07             Quel
# 5583          5606   Paulinho Villas Boas  1963-01-26        São Paulo
# 5599          5622      Vladimir Andreyev  1945-06-14        Astrakhan
# 5609          5632        Franjo Arapović  1965-06-02              NaN
# ...            ...                    ...         ...              ...
# 140298      143804       Aaron Geramipoor  1992-09-11        Stockport
# 141018      144554          Yuta Watanabe  1994-10-13  Ayauta district
# 142044      145640          Jahlil Okafor  1995-12-15       Fort Smith
# 142930      146560             Mike Tobey  1994-10-10           Monroe
# 143712      147367           JaVale McGee  1988-01-19            Flint
#
#        born_region born_country                       NOC  height_cm  \
# 5089        Moskva          RUS              Soviet Union      220.0
# 5572      La Rioja          ESP                     Spain      213.0
# 5583     São Paulo          BRA                    Brazil      217.0
# 5599     Astrakhan          RUS              Soviet Union      215.0
# 5609           NaN          NaN        Croatia Yugoslavia      211.0
# ...            ...          ...                       ...        ...
# 140298     England          GBR  Islamic Republic of Iran      214.0
# 141018      Kagawa          JPN                     Japan      215.0
# 142044    Arkansas          USA                   Nigeria      211.0
# 142930    New York          USA                  Slovenia      213.0
# 143712    Michigan          USA             United States      213.0
#
#         weight_kg   died_date
# 5089        112.0  1993-07-24
# 5572         98.0         NaN
# 5583        106.0         NaN
# 5599         90.0         NaN
# 5609        120.0         NaN
# ...           ...         ...
# 140298        NaN         NaN
# 141018       97.0         NaN
# 142044        NaN         NaN
# 142930        NaN         NaN
# 143712        NaN         NaN
#
# [150 rows x 10 columns]

# %%
#multiple conditions
players[(players['height_cm'] > 210) & (players['born_country'] == 'USA')]
# Out:
#         athlete_id                name   born_date         born_city  \
# 5681          5704        Walt Bellamy  1937-07-24          New Bern
# 5781          5804      Tommy Burleson  1952-02-24         Crossnore
# 5894          5919          Mel Counts  1941-10-16          Coos Bay
# 6106          6133     Marc Freiberger  1928-11-27          Amarillo
# 6281          6309      Darrall Imhoff  1938-10-11       San Gabriel
# 6379          6410          Joe Kleine  1962-01-04  Colorado Springs
# 6393          6424          Jon Koncak  1963-05-17      Cedar Rapids
# 6442          6473  Christian Laettner  1969-08-17            Angola
# 6615          6648        Tom McMillen  1952-05-26         Mansfield
# 6722          6755    Shaquille O'Neal  1972-03-06            Newark
# 6937          6972      David Robinson  1965-08-06          Key West
# 7012          7048     Daniel Santiago  1976-06-24    Tarpon Springs
# 112319      113575         Chris Kaman  1982-04-28           Wyoming
# 112366      113622       Dwight Howard  1985-12-08           Atlanta
# 118573      120309     Al-Farouq Aminu  1990-09-21           Atlanta
# 123850      126093      Tyson Chandler  1982-10-02           Hanford
# 132188      135037    Domantas Sabonis  1996-05-03          Portland
# 133332      136271      DeAndre Jordan  1988-07-21           Houston
# 142044      145640       Jahlil Okafor  1995-12-15        Fort Smith
# 142930      146560          Mike Tobey  1994-10-10            Monroe
# 143712      147367        JaVale McGee  1988-01-19             Flint
#
#            born_region born_country            NOC  height_cm  weight_kg  \
# 5681    North Carolina          USA  United States      211.0       98.0
# 5781    North Carolina          USA  United States      223.0      102.0
# 5894            Oregon          USA  United States      213.0      102.0
# 6106             Texas          USA  United States      211.0       98.0
# 6281        California          USA  United States      211.0       98.0
# 6379          Colorado          USA  United States      211.0      122.0
# 6393              Iowa          USA  United States      213.0      113.0
# 6442          New York          USA  United States      211.0      107.0
# 6615      Pennsylvania          USA  United States      212.0       95.0
# 6722        New Jersey          USA  United States      216.0      137.0
# 6937           Florida          USA  United States      216.0      107.0
# 7012           Florida          USA    Puerto Rico      213.0      111.0
# 112319        Michigan          USA        Germany      213.0      122.0
# 112366         Georgia          USA  United States      211.0      120.0
# 118573         Georgia          USA        Nigeria      211.0       98.0
# 123850      California          USA  United States      216.0      107.0
# 132188          Oregon          USA      Lithuania      211.0      109.0
# 133332           Texas          USA  United States      211.0      120.0
# 142044        Arkansas          USA        Nigeria      211.0        NaN
# 142930        New York          USA       Slovenia      213.0        NaN
# 143712        Michigan          USA  United States      213.0        NaN
#
#          died_date
# 5681    2013-11-02
# 5781           NaN
# 5894           NaN
# 6106    2005-06-29
# 6281    2017-06-30
# 6379           NaN
# 6393           NaN
# 6442           NaN
# 6615           NaN
# 6722           NaN
# 6937           NaN
# 7012           NaN
# 112319         NaN
# 112366         NaN
# 118573         NaN
# 123850         NaN
# 132188         NaN
# 133332         NaN
# 142044         NaN
# 142930         NaN
# 143712         NaN

# %%
# finding players starting with a specific name
players[players['name'].str.contains('Keith')]
players[players['name'].str.contains('keith', case=False)] #case sensitive even if i put small letter
players[players['born_region'] == 'California']
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# 1346          1353       Gillian Boxx  1973-09-01           Fontana
# ...            ...                ...         ...               ...
# 145383      149106     Tyler Wallasch  1994-06-08       Los Angeles
# 145387      149110          Alysa Liu  2005-08-08            Clovis
# 145402      149125    Brendan Brisson  2001-10-22   Manhattan Beach
# 145430      149153       Robert Burns  1990-11-11      Mount Shasta
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
#
#        born_region born_country            NOC  height_cm  weight_kg died_date
# 54      California          USA  Great Britain      177.0       64.0       NaN
# 960     California          USA         Mexico      170.0       60.0       NaN
# 961     California          USA         Mexico      160.0       54.0       NaN
# 1345    California          USA  United States      168.0       61.0       NaN
# 1346    California          USA  United States      170.0        NaN       NaN
# ...            ...          ...            ...        ...        ...       ...
# 145383  California          USA  United States        NaN        NaN       NaN
# 145387  California          USA  United States        NaN        NaN       NaN
# 145402  California          USA  United States        NaN        NaN       NaN
# 145430  California          USA  United States        NaN        NaN       NaN
# 145457  California          USA  United States        NaN        NaN       NaN
#
# [1634 rows x 10 columns]

# %%
#using QUERY function
players.query('born_country == "USA"')
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# 960      California          USA         Mexico      170.0       60.0
# 961      California          USA         Mexico      160.0       54.0
# 1231           Ohio          USA         Canada        NaN        NaN
# 1345     California          USA  United States      168.0       61.0
# ...             ...          ...            ...        ...        ...
# 145445  Connecticut          USA  United States        NaN        NaN
# 145446   Washington          USA  United States        NaN        NaN
# 145454    Wisconsin          USA  United States        NaN        NaN
# 145457   California          USA  United States        NaN        NaN
# 145468     Michigan          USA  United States      187.0       97.0
#
#          died_date
# 54             NaN
# 960            NaN
# 961            NaN
# 1231    1986-02-20
# 1345           NaN
# ...            ...
# 145445         NaN
# 145446         NaN
# 145454         NaN
# 145457         NaN
# 145468         NaN
#
# [9641 rows x 10 columns]

# %%
players.query('born_country == "USA" and born_city =="Los Angeles"')
# Out:
#         athlete_id                 name   born_date    born_city born_region  \
# 2659          2671  Tamarine Tanasugarn  1977-05-24  Los Angeles  California
# 3236          3248          Augie Ojeda  1974-12-20  Los Angeles  California
# 4578          4594            Al Romero  1911-09-06  Los Angeles  California
# 5491          5512         Misty Thomas  1964-07-01  Los Angeles  California
# 6522          6555          Frank Lubin  1910-01-07  Los Angeles  California
# ...            ...                  ...         ...          ...         ...
# 143709      147364         Jrue Holiday  1990-06-12  Los Angeles  California
# 143762      147417           Nick Itkin  1999-10-09  Los Angeles  California
# 143765      147421      Collin Morikawa  1997-02-06  Los Angeles  California
# 144057      147722      Khalil Thompson  1997-02-03  Los Angeles  California
# 145383      149106       Tyler Wallasch  1994-06-08  Los Angeles  California
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 2659            USA       Thailand      165.0       60.0         NaN
# 3236            USA  United States      175.0       79.0         NaN
# 4578            USA         Mexico      170.0        NaN  1985-09-30
# 5491            USA         Canada      180.0       68.0         NaN
# 6522            USA  United States      200.0      113.0  1999-07-08
# ...             ...            ...        ...        ...         ...
# 143709          USA  United States      190.0       93.0         NaN
# 143762          USA  United States        NaN        NaN         NaN
# 143765          USA  United States      175.0       73.0         NaN
# 144057          USA  United States        NaN        NaN         NaN
# 145383          USA  United States        NaN        NaN         NaN
#
# [230 rows x 10 columns]
