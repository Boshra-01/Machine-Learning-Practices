# %% [markdown]
# <a href="https://colab.research.google.com/github/Boshra-01/Machine-Learning-Practices/blob/main/ML_Model_Scikit_Learn_of_Solubility_of_Molecules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Solubility of Molecules**
# ##### Important for chemists and biologists to determine whether a molecule is soluble in water and whether they are good drug candidates #####
# ###### (inspired by pharmacist sibling!) #####

# %% [markdown]
# ## Load data (multi variant analysis: y=f(x))

# %%
import pandas as pd

data_frame_var = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
data_frame_var
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# ## ***Data Preparation for Analysis***

# %% [markdown]
# ### Data separation as X & Y. Y is target

# %%
y = data_frame_var['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = data_frame_var.drop('logS', axis =1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.3, random_state=100)

x_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 166  5.31380  257.547                1.0            0.800000
# 97  -0.92640  126.115                0.0            0.666667
# 714 -0.77160  151.129                0.0            0.818182
# 328  0.49100  208.217                4.0            0.000000
# 191  3.60230  207.070                0.0            0.909091
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [800 rows x 4 columns]

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 863   2.65122  266.304                1.0            0.600000
# 395   4.33190  367.860                7.0            0.285714
# 1106  3.27520  148.249                1.0            0.545455
# 374   5.27020  364.914                0.0            0.000000
# 678   2.79932  277.238                5.0            0.352941
#
# [344 rows x 4 columns]

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### Training a model

# %%
# sciket lear# sklearn has multiple functions as linear regression to prepare dataset and prepare ML models
from sklearn.linear_model import LinearRegression
linear_regression_var = LinearRegression()
# we want to train the empty linearegression model on the following:
linear_regression_var.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Applying the model to make prediction**

# %%
y_linReg_train_predition = linear_regression_var.predict(x_train)
y_linReg_test_prediction = linear_regression_var.predict(x_test)

# print(y_linReg_train_predition, y_linReg_test_prediction)
# prediction of training data: y_linReg_train_predition #prediction of testing data: y_linReg_test_prediction
y_linReg_train_predition
# Out:
# array([-5.76071748, -0.21138632, -0.56320332, -1.47672665, -4.21552033,
#        -5.33655234, -5.32589636, -4.7089393 , -2.57194987, -1.90324945,
#        -5.02321513, -1.30655385, -4.94140205, -5.76071748, -1.610082  ,
#        -0.48583337, -2.81243736, -3.42081155, -3.76500782, -2.12630913,
#        -2.34746617, -4.47425322, -1.37321128, -3.00263554, -1.09378855,
#        -2.67067504, -2.04745838, -3.84832952, -3.42081155, -3.90563247,
#        -1.61731792, -1.65488328, -2.23218649, -2.34270592, -4.02336375,
#        -0.42737422, -3.74298037, -3.22054052, -3.29878574, -3.49962987,
#        -0.70813304, -4.63447041, -2.54118351, -1.56708316,  0.10143769,
#        -2.05929668, -2.51119515, -5.15394258, -3.81239337, -2.08068271,
#        -3.10592638, -5.08339507, -4.5569984 , -0.56833521, -2.1094789 ,
#        -0.15568756, -2.17445427, -3.91687761, -7.89695189, -1.74991439,
#        -3.92357517, -1.17828918, -5.41457689, -0.36236626, -5.15565764,
# ...

# %% [markdown]
# ### **Evaluate Model Performance**

# %%
# actual value of y
y_train
# Out:
# 166   -6.270
# 97    -0.807
# 714   -3.583
# 328   -2.077
# 191   -4.400
#        ...
# 802   -2.925
# 53    -2.680
# 350   -7.020
# 79    -4.800
# 792   -3.240
# Name: logS, Length: 800, dtype: float64

# %%
# predicted value of y
y_linReg_train_predition
# Out:
# array([-5.76071748, -0.21138632, -0.56320332, -1.47672665, -4.21552033,
#        -5.33655234, -5.32589636, -4.7089393 , -2.57194987, -1.90324945,
#        -5.02321513, -1.30655385, -4.94140205, -5.76071748, -1.610082  ,
#        -0.48583337, -2.81243736, -3.42081155, -3.76500782, -2.12630913,
#        -2.34746617, -4.47425322, -1.37321128, -3.00263554, -1.09378855,
#        -2.67067504, -2.04745838, -3.84832952, -3.42081155, -3.90563247,
#        -1.61731792, -1.65488328, -2.23218649, -2.34270592, -4.02336375,
#        -0.42737422, -3.74298037, -3.22054052, -3.29878574, -3.49962987,
#        -0.70813304, -4.63447041, -2.54118351, -1.56708316,  0.10143769,
#        -2.05929668, -2.51119515, -5.15394258, -3.81239337, -2.08068271,
#        -3.10592638, -5.08339507, -4.5569984 , -0.56833521, -2.1094789 ,
#        -0.15568756, -2.17445427, -3.91687761, -7.89695189, -1.74991439,
#        -3.92357517, -1.17828918, -5.41457689, -0.36236626, -5.15565764,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

linReg_train_mse = mean_squared_error(y_train, y_linReg_train_predition)
linReg_train_r2 = r2_score(y_train, y_linReg_train_predition)

linReg_test_mse = mean_squared_error(y_test, y_linReg_test_prediction)
linReg_test_r2 = r2_score(y_test, y_linReg_test_prediction)

# %%
# actual model evaluation:
#training
print('LR MSE (Train): ', linReg_train_mse)
print('LR R2 (Train): ', linReg_train_r2)
#testing
print('LR MSE (Test): ', linReg_test_mse)
print('LR R2 (Test): ', linReg_test_r2)
# Out:
# LR MSE (Train):  1.0529225546973289
# LR R2 (Train):  0.7594328521298884
# LR MSE (Test):  0.9134877174659213
# LR R2 (Test):  0.7935230672635001

# %% [markdown]
# **Implementing Pandas**

# %%
linReg_results = pd.DataFrame (['Linear Regression', linReg_train_mse, linReg_train_r2, linReg_test_mse, linReg_test_r2]).transpose()
linReg_results
# Out:
#                    0         1         2         3         4
# 0  Linear Regression  1.052923  0.759433  0.913488  0.793523

# %% [markdown]
# **Renaming Columns:**

# %%
linReg_results.columns = ['Methods','Training MSE', 'Training R2', 'Test MSE', 'Test R2']
linReg_results
# Out:
#              Methods Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.052923    0.759433  0.913488  0.793523

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# ### **Training the Model**
# y variable is quantitative, so 'RandomForestRegressor' is used for Regression model. If y was categorical, then the model would have been 'Classification' as RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
# train the model:
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### **Applying the model to make a prediction**

# %%
y_rf_train_predition = rf.predict(x_train)
y_rf_test_prediction = rf.predict(x_test)

# %% [markdown]
# ### **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_predition)
rf_train_r2 = r2_score(y_train, y_rf_train_predition)

rf_test_mse = mean_squared_error(y_test, y_rf_test_prediction)
rf_test_r2 = r2_score(y_test, y_rf_test_prediction)

# %%
rf_results = pd.DataFrame (['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Methods','Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#          Methods Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     1.013169    0.768516  1.192066  0.730556

# %% [markdown]
# ## **Model Comparison**

# %%
df_models = pd.concat([linReg_results, rf_results], axis=0)
df_models
# Out:
#              Methods Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.052923    0.759433  0.913488  0.793523
# 0      Random Forest     1.013169    0.768516  1.192066  0.730556

# %%
df_models.reset_index(drop=True)
# Out:
#              Methods Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.052923    0.759433  0.913488  0.793523
# 1      Random Forest     1.013169    0.768516  1.192066  0.730556

# %% [markdown]
# ### **Data Visualization of predicted results**

# %%
import matplotlib.pyplot as plt
plt.scatter(x=y_train, y=y_linReg_train_predition)
plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
plt.scatter(x=y_train, y=y_linReg_train_predition, alpha=0.3)
plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
plt.scatter(x=y_train, y=y_linReg_train_predition, c="#7CAE00", alpha=0.3)

plt.plot()
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')

# %% [markdown]
# ### **Adding Trendline with Numpy**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(x=y_train, y=y_linReg_train_predition, c="#7CAE00", alpha=0.3)

z = np.polyfit(y_train, y_linReg_train_predition, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#000000' )
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
